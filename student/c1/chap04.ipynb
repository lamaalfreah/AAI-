# %% [markdown]
# Name: Lama Alfreah.

# %% [markdown]
# To use the `jupyturtle` module, we can import it like this.

# %%
import jupyturtle
from jupyturtle import make_turtle, forward, left, penup, pendown

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose

# %% [markdown]
# For the exercises below, there are a few more turtle functions you might want to use.
#
# * `penup` lifts the turtle's imaginary pen so it doesn't leave a trail when it moves.
#
# * `pendown` puts the pen back down.
#
# The following function uses `penup` and `pendown` to move the turtle without leaving a trail.

# %%
from jupyturtle import penup, pendown

def jump(length):
    """Move forward length units without leaving a trail.

    Postcondition: Leaves the pen down.
    """
    penup()
    forward(length)
    pendown()

# %% [markdown]
# ### Exercise
#
# Write a function called `rectangle` that draws a rectangle with given side lengths.
# For example, here's a rectangle that's `80` units wide and `40` units tall.

# %%
def rectangle(width, height):    
    for i in range(2):
        forward(width)
        left(90)
        forward(height)
        left(90)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rectangle(80, 40)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 230,75 230,35 150,35 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write a function called `rhombus` that draws a rhombus with a given side length and a given interior angle. For example, here's a rhombus with side length `50` and an interior angle of `60` degrees.

# %%
def rhombus(length, angle):    
    for i in range(2):
        forward(length)
        left(angle)
        forward(length)
        left(180 - angle)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rhombus(50, 60)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 200,75 225,31.7 175,31.7 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Now write a more general function called `parallelogram` that draws a quadrilateral with parallel sides. Then rewrite `rectangle` and `rhombus` to use `parallelogram`.

# %%
def parallelogram(width, height, angle):
    for _ in range(2):
        forward(width)
        left(angle)
        forward(height)
        left(180 - angle)

# %%
def rectangle(width, height):
    parallelogram(width, height, 90)

# %%
def rhombus(side, angle):
    parallelogram(side, side, angle)

# %% [markdown]
# You can use the following code to test your functions.

# %%
make_turtle(width=400)
jump(-120)

rectangle(80, 40)
jump(100)
rhombus(50, 60)
jump(80)
parallelogram(80, 50, 60)
# Out:
# <svg width="400" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 200,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 80,75 160,75 160,35 80,35 80,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 180,75 230,75 255,31.7 205,31.7 180,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 260,75 340,75 365,31.7 285,31.7 260,75" />'
#
# <g transform="rotate(-90.0,260.0,75.0) translate(260.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw shapes like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_pie.png)
#
# Hint: Write a function called `triangle` that draws one triangular segment, and then a function called `draw_pie` that uses `triangle`.

# %%
# Solution goes here

# %%
# Solution goes here

# %% [markdown]
# You can use the following code to test your functions.

# %%
turtle = make_turtle(delay=0)
jump(-80)

size = 40
draw_pie(5, size)
jump(2*size)
draw_pie(6, size)
jump(2*size)
draw_pie(7, size)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 70,75 110,75 97.6,37 65.3,60.5 32.9,84 65.3,107.5 77.6,69.4 90,31.4 50,31.4 62.4,69.4 74.7,107.5 107.1,84 74.7,60.5 42.4,37 30,75 70,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 190,75 170,40.4 150,75 130,109.6 170,109.6 150,75 130,40.4 110,75 150,75 190,75 170,40.4 150,75 130,109.6 170,109.6 150,75 130,40.4 110,75 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 230,75 270,75 245.1,43.7 236.2,82.7 227.3,121.7 263.3,104.4 227.3,87 191.2,69.7 200.1,108.7 225.1,77.4 250,46.1 210,46.1 234.9,77.4 259.9,108.7 268.8,69.7 232.7,87 196.7,104.4 232.7,121.7 223.8,82.7 214.9,43.7 190,75 230,75" />'
#
# <g transform="rotate(-90.0,230.0,75.0) translate(230.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw flowers like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_flower.png)
#
# Hint: Use `arc` to write a function called `petal` that draws one flower petal.

# %%
def arc(radius, angle):
    arc_length = 2 * 3.14159 * radius * angle / 360
    n = int(arc_length / 3) + 1
    step_length = arc_length / n
    step_angle = angle / n
    for i in range(n):
        forward(step_length)
        left(step_angle)

def petal(radius, angle):
    for i in range(2):
        arc(radius, angle)
        left(180 - angle)

def flower(n, radius, angle):
    for i in range(n):
        petal(radius, angle)
        left(360 / n)

# %%
# Solution goes here

# %% [markdown]
# You can use the following code to test your functions.
#
# Because the solution draws a lot of small line segments, it tends to slow down as it runs.
# To avoid that, you can add the keyword argument `auto_render=False` to avoid drawing after every step, and then call the `render` function at the end to show the result.
#
# While you are debugging, you might want to remove `auto_render=False`.

# %%
turtle = make_turtle(delay=0)
jump(-60)
n = 7
radius = 60
angle = 60
flower(n, radius, angle)

jump(120)
n = 9
radius = 40
angle = 85
flower(n, radius, angle)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 90,75 93,75 96,74.9 99,74.6 101.9,74.1 104.8,73.5 107.7,72.8 110.6,71.9 113.4,70.9 116.2,69.7 118.9,68.4 121.5,67 124.1,65.4 126.5,63.7 128.9,61.9 131.2,60 133.4,58 135.5,55.8 137.5,53.6 139.3,51.2 141.1,48.8 142.7,46.3 139.7,46.3 136.7,46.5 133.7,46.7 130.8,47.2 127.9,47.8 125,48.5 122.1,49.4 119.3,50.4 116.5,51.6 113.8,52.9 111.2,54.3 108.6,55.9 106.2,57.6 103.8,59.4 101.5,61.3 99.3,63.3 97.2,65.5 95.2,67.7 93.4,70.1 91.6,72.5 90,75 91.9,72.7 93.6,70.2 95.2,67.7 96.7,65.1 98.1,62.5 99.3,59.7 100.4,57 101.4,54.1 102.2,51.2 102.8,48.3 103.4,45.4 103.7,42.4 104,39.4 104,36.4 104,33.4 103.7,30.5 103.4,27.5 102.8,24.5 102.2,21.6 101.4,18.7 100.4,15.9 98.6,18.2 96.8,20.7